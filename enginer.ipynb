# %%
#Se preparan los datos para las consultas de la API

# %%
#Se importan las librerias que se van a usar.

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %load_ext autoreload
# %autoreload 2
import functions
import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Se extraen los datos limpios de los archivos CSV
df_games = pd.read_csv("data\output_steam_games.csv") #Contiene inormacion de los juegos de la plataforma

df_users = pd.read_csv("data\oaustralian_users_items.csv") #Contiene informacion sobre los juegos de cada usuario

df_reviews = pd.read_csv('data\oaustralian_user_review.csv') #Contiene informacion sobre las reviews hechas por los usuarios

# %% [markdown]
# Se pide hacer un analisis de sentimientos para los comentarios, utilizando la siguiente escala:
#  0 es negativo
#  1 es neutral o no tiene review
#  2 es positivo
#   El objetivo es conseguir un producto minimo viable se va a realizar un analisi de sentimiento basico con TextBlob.
#   Dicha libreria usa un sistema de procesamiento de lenguaje natural.

# %%
df_reviews["sentiment_analysis"] = df_reviews["reviews_review"].apply(functions.sentimientos)

# %%
#Se revisan algunos ejemplos para cada clase de sentimiento

# %%
df_reviews[df_reviews["sentiment_analysis"]== 0]
# Out:
#                         user_id  \
# 5                        Wackky
# 7                   MeaTCompany
# 8             76561198089393905
# 14                     DJKamBer
# 16            76561198043472122
# ...                         ...
# 57357                   bmayall
# 57359  adamdacheeseburger139146
# 57361            kushikushigani
# 57363         76561198111410893
# 57366              EchoXSilence
#
#                                                 user_url    reviews_posted  \
# 5                    http://steamcommunity.com/id/Wackky        2014-05-05
# 7               http://steamcommunity.com/id/MeaTCompany  Formato invalido
# 8      http://steamcommunity.com/profiles/76561198089...        2015-02-01
# 14                 http://steamcommunity.com/id/DJKamBer        2014-07-14
# 16     http://steamcommunity.com/profiles/76561198043...        2014-12-19
# ...                                                  ...               ...
# ...

# %%
df_reviews[df_reviews["sentiment_analysis"]== 1]
# Out:
#                  user_id                                           user_url  \
# 4              maplemage             http://steamcommunity.com/id/maplemage
# 6      76561198079601835  http://steamcommunity.com/profiles/76561198079...
# 10     76561198077246154  http://steamcommunity.com/profiles/76561198077...
# 11            WeiEDKrSat            http://steamcommunity.com/id/WeiEDKrSat
# 12         thequeenpanda         http://steamcommunity.com/id/thequeenpanda
# ...                  ...                                                ...
# 57348        haaaagaaaay           http://steamcommunity.com/id/haaaagaaaay
# 57352             Skye04                http://steamcommunity.com/id/Skye04
# 57354            mamat08               http://steamcommunity.com/id/mamat08
# 57355  76561198098137546  http://steamcommunity.com/profiles/76561198098...
# 57358         2092000666            http://steamcommunity.com/id/2092000666
#
#          reviews_posted  reviews_item_id  \
# ...

# %%
df_reviews[df_reviews["sentiment_analysis"]== 2]
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 9      76561198156664158  http://steamcommunity.com/profiles/76561198156...
# ...                  ...                                                ...
# 57356  76561198100193015  http://steamcommunity.com/profiles/76561198100...
# 57360  76561198107177722  http://steamcommunity.com/profiles/76561198107...
# 57362              How51                 http://steamcommunity.com/id/How51
# 57364            zaza147               http://steamcommunity.com/id/zaza147
# 57365         lifeonhigh            http://steamcommunity.com/id/lifeonhigh
#
#          reviews_posted  reviews_item_id  \
# ...

# %%
#se elimina la columna reviews_review
df_reviews.drop(columns=["reviews_review"],inplace=True)

# %%
df_users
# Out:
#          item_id                      item_name  playtime_forever  \
# 0             10                 Counter-Strike                 6
# 1             20          Team Fortress Classic                 0
# 2             30                  Day of Defeat                 7
# 3             40             Deathmatch Classic                 0
# 4             50      Half-Life: Opposing Force                 0
# ...          ...                            ...               ...
# 5094100   346330                   BrainBread 2                 0
# 5094101   373330                    All Is Dust                 0
# 5094102   388490  One Way To Die: Steam Edition                 3
# 5094103   521570          You Have 10 Seconds 2                 4
# 5094104   519140                     Minds Eyes                 3
#
#                   steam_id  items_count            user_id  \
# 0        76561197970982479          277  76561197970982479
# ...

# %%
df_games
# Out:
#            genres  price  early_access      id release_year     publisher  \
# 0          Action   4.99         False  761140         2018     Kotoshiro
# 1          Casual   4.99         False  761140         2018     Kotoshiro
# 2           Indie   4.99         False  761140         2018     Kotoshiro
# 3      Simulation   4.99         False  761140         2018     Kotoshiro
# 4        Strategy   4.99         False  761140         2018     Kotoshiro
# ...           ...    ...           ...     ...          ...           ...
# 71546       Indie   1.99         False  610660         2018  Laush Studio
# 71547      Racing   1.99         False  610660         2018  Laush Studio
# 71548  Simulation   1.99         False  610660         2018  Laush Studio
# 71549      Casual   4.99         False  658870         2017      SIXNAILS
# 71550       Indie   4.99         False  658870         2017      SIXNAILS
#
#                   app_name                title                 developer
# ...

# %%
df_games.rename(columns= {"id":"item_id"} ,inplace =True)

# %%
df_horas_por_juego_anio = pd.merge(df_games,df_users,on = "item_id",how = "inner" )

# %%
df_horas_por_juego_anio
# Out:
#          genres  price  early_access  item_id release_year  \
# 0        Action   9.99         False   282010         1997
# 1        Action   9.99         False   282010         1997
# 2        Action   9.99         False   282010         1997
# 3        Action   9.99         False   282010         1997
# 4        Action   9.99         False   282010         1997
# ...         ...    ...           ...      ...          ...
# 9877299  Action   9.99         False       80         2004
# 9877300  Action   9.99         False       80         2004
# 9877301  Action   9.99         False       80         2004
# 9877302  Action   9.99         False       80         2004
# 9877303  Action   9.99         False       80         2004
#
#                    publisher                        app_name  \
# 0        Stainless Games Ltd            Carmageddon Max Pack
# 1        Stainless Games Ltd            Carmageddon Max Pack
# 2        Stainless Games Ltd            Carmageddon Max Pack
# ...

# %%
#se eliminan columnas que no se van a usar
columnas = ["price","early_access","app_name", "developer","publisher","user_url" ]
df_horas_por_juego_anio.drop(columnas, axis =1 , inplace = True)

# %%
df_horas_por_juego_anio
# Out:
#          genres  item_id release_year                           title  \
# 0        Action   282010         1997            Carmageddon Max Pack
# 1        Action   282010         1997            Carmageddon Max Pack
# 2        Action   282010         1997            Carmageddon Max Pack
# 3        Action   282010         1997            Carmageddon Max Pack
# 4        Action   282010         1997            Carmageddon Max Pack
# ...         ...      ...          ...                             ...
# 9877299  Action       80         2004  Counter-Strike: Condition Zero
# 9877300  Action       80         2004  Counter-Strike: Condition Zero
# 9877301  Action       80         2004  Counter-Strike: Condition Zero
# 9877302  Action       80         2004  Counter-Strike: Condition Zero
# 9877303  Action       80         2004  Counter-Strike: Condition Zero
#
#                               item_name  playtime_forever           steam_id  \
# ...

# %%
table = pa.Table.from_pandas(df_horas_por_juego_anio)

# %%
ruta = "data/horas_juego.parquet"   
pq.write_table(table,ruta)

# %%
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 57362              How51                 http://steamcommunity.com/id/How51
# 57363  76561198111410893  http://steamcommunity.com/profiles/76561198111...
# 57364            zaza147               http://steamcommunity.com/id/zaza147
# 57365         lifeonhigh            http://steamcommunity.com/id/lifeonhigh
# 57366       EchoXSilence          http://steamcommunity.com/id/EchoXSilence
#
#          reviews_posted  reviews_item_id  \
# ...

# %%
#se crea un dataframe usaniendo los dataframe df_games y df_reviews para realizar un sistema de recomendaciones
df_reviews_year = pd.merge(df_games,df_reviews.rename(columns= {"reviews_item_id":"item_id"}),on = "item_id",how = "inner" )

# %%
df_reviews_year
# Out:
#         genres  price  early_access  item_id release_year  \
# 0       Action   9.99         False   282010         1997
# 1        Indie   9.99         False   282010         1997
# 2       Racing   9.99         False   282010         1997
# 3       Action   9.99         False       70         1998
# 4       Action   9.99         False       70         1998
# ...        ...    ...           ...      ...          ...
# 122014  Action   9.99         False       80         2004
# 122015  Action   9.99         False       80         2004
# 122016  Action   9.99         False       80         2004
# 122017  Action   9.99         False       80         2004
# 122018  Action   9.99         False       80         2004
#
#                   publisher                        app_name  \
# 0       Stainless Games Ltd            Carmageddon Max Pack
# 1       Stainless Games Ltd            Carmageddon Max Pack
# 2       Stainless Games Ltd            Carmageddon Max Pack
# ...

# %%
#se elimnan las columnas que no se van a usar
columnas = ["developer", "user_id", "price", "genres", "early_access" ,"publisher", "app_name","developer","user_url", "release_year", "reviews_helpful"]
df_reviews_year.drop(columnas, axis = 1, inplace= True)

# %%
df_reviews_year
# Out:
#         item_id                           title    reviews_posted  \
# 0        282010            Carmageddon Max Pack  Formato invalido
# 1        282010            Carmageddon Max Pack  Formato invalido
# 2        282010            Carmageddon Max Pack  Formato invalido
# 3            70                       Half-Life        2015-10-28
# 4            70                       Half-Life        2014-07-01
# ...         ...                             ...               ...
# 122014       80  Counter-Strike: Condition Zero        2014-10-26
# 122015       80  Counter-Strike: Condition Zero        2013-12-08
# 122016       80  Counter-Strike: Condition Zero        2011-12-28
# 122017       80  Counter-Strike: Condition Zero        2014-03-09
# 122018       80  Counter-Strike: Condition Zero        2014-12-06
#
#         reviews_recommend  sentiment_analysis
# 0                    True                   1
# 1                    True                   1
# ...

# %%
# se eliminan los que no tienen fecha de review
df_reviews_year = df_reviews_year[df_reviews_year["reviews_posted"] != "Formato invalido"]

# %%
df_reviews_year
# Out:
#         item_id                           title reviews_posted  \
# 3            70                       Half-Life     2015-10-28
# 4            70                       Half-Life     2014-07-01
# 8            70                       Half-Life     2015-01-04
# 9            70                       Half-Life     2014-01-01
# 10           70                       Half-Life     2011-06-18
# ...         ...                             ...            ...
# 122014       80  Counter-Strike: Condition Zero     2014-10-26
# 122015       80  Counter-Strike: Condition Zero     2013-12-08
# 122016       80  Counter-Strike: Condition Zero     2011-12-28
# 122017       80  Counter-Strike: Condition Zero     2014-03-09
# 122018       80  Counter-Strike: Condition Zero     2014-12-06
#
#         reviews_recommend  sentiment_analysis
# 3                    True                   0
# 4                    True                   0
# 8                    True                   2
# ...

# %%
# Se extrae el año de la fecha de posteo de la review

df_reviews_year["reviews_posted"] = pd.to_datetime(df_reviews_year["reviews_posted"]).dt.year

# %%
df_reviews_year["reviews_posted"].dtype
# Out:
# dtype('int32')

# %%
df_reviews_year
# Out:
#         item_id                           title  reviews_posted  \
# 3            70                       Half-Life            2015
# 4            70                       Half-Life            2014
# 8            70                       Half-Life            2015
# 9            70                       Half-Life            2014
# 10           70                       Half-Life            2011
# ...         ...                             ...             ...
# 122014       80  Counter-Strike: Condition Zero            2014
# 122015       80  Counter-Strike: Condition Zero            2013
# 122016       80  Counter-Strike: Condition Zero            2011
# 122017       80  Counter-Strike: Condition Zero            2014
# 122018       80  Counter-Strike: Condition Zero            2014
#
#         reviews_recommend  sentiment_analysis
# 3                    True                   0
# 4                    True                   0
# 8                    True                   2
# ...

# %%
#se almacena el dataframe en un archivo parquet
ruta = "data/df_reviews_year.parquet"
table = pa.Table.from_pandas(df_reviews_year)
pq.write_table(table,ruta)
